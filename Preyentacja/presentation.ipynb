# %% [markdown]
# # Data retrieval - inverted index
# ## Skip lists ( and positional indexes?)
# **Paweł Kruczkiewicz**

# %%
# All imports
from pathlib import Path
from Lib import traceback
import os
from functools import reduce

from time import time
from IPython.display import Video

from math import sqrt, ceil

# all_folder_names
images = Path("dataset/images")
sw_video = Path("dataset/star_wars_video")
sw_scripts = Path("dataset/star_wars_scripts")
all_scripts = Path("dataset/all_scripts")

sw_lemmas_dir = Path("dataset/lemmas_star_wars")
all_lemmas_dir = Path("dataset/lemmas_all_scripts")
#time measure function
def measure_time(func, message):
    t_start = time()
    result = func()
    t_end = time()
    print(f"{message}: {t_end - t_start} [s]")
    return result

# %%
#source: https://www.youtube.com/watch?v=5GFW-eEWXlc
Video(sw_video / "arst_arsw_edit.mp4")
# Out:
# <video src="dataset\star_wars_video\arst_arsw_edit.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Ale po co to wszystko?

# %% [markdown]
# ### Nie wiem...

# %% [markdown]
# ### Zatem znajdźmy sobie jakiś własny cel!

# %% [markdown]
# Przypuśćmy, że chcemy wiedzieć dokładnie, w której filmowej części *Gwiezdnych Wojen* zostały zawarte słowa "Luke" oraz "Leia" (jest to tzw. *Boolean retrieval*)

# %% [markdown]
# #### I sposób - *grepping*
# Liniowe przejście po tekście
#
# 1. Wczytanie potrzebnych dokumentów i ponumerowanie ich (tzw. *indeksacja*)
# 2. Dla każdego dokumentu: Iteracja po każdym wyrazie i sprawdzenie, czy wyraz zawiera się w dokumecie.
# 3. Przecięcie zbiorów jest szukanym wyrażeniem.

# %%
# 1. wczytanie dokumentów 
def open_document(path):
    with open(path, "r", encoding="UTF-8") as file:
        text = file.read()
    words = list(map(lambda word: word.strip(), text.split()))
    return words

def get_words_in_docs_from_dir(dir_name):
    cwd = os.getcwd()
    os.chdir(dir_name)
    words_in_docs = []
    try:
        for doc_path in os.listdir():
            words_in_docs.append(open_document(doc_path))
    except FileNotFoundError:
        traceback.print_exc()
    finally:
        os.chdir(cwd)
    
    return words_in_docs

sw_words = get_words_in_docs_from_dir(sw_scripts)
doc_indexes= [1,2,3,4,5,6,7]  # from Phantom Menace to Force Awakenes

no_words = sum(list(map(len, sw_words)))   # not neccessarly unique words
print(f"\nTotal number of words: {no_words}")
# Out:
# Total number of words: 194102

# %%
# 2. iteracja po dokumentac i wyszukiwanie słów

def is_word_in_doc(query_word, doc):
    for word in doc:  # można zapisac to w jednej linii, ale tak widac, że jest to liniowe
        if query_word == word:
            return True
    return False

def docs_with_query_word(query_word, docs):
    result = set()
    for i, doc in enumerate(docs):
        if is_word_in_doc(query_word, doc):
            result.add(doc_indexes[i])
    return result

episodes_with_luke = docs_with_query_word("Luke", sw_words)
episodes_with_leia = docs_with_query_word("Leia", sw_words)

print(f"Luke Skywalker was mentioned in episodes {episodes_with_luke}")
print(f"Leia Organa was mentioned in episodes {episodes_with_leia}")
# Out:
# Luke Skywalker was mentioned in episodes {3, 4, 5, 6, 7}
# Leia Organa was mentioned in episodes {4, 5, 6, 7}

# %%
# 3. Część wspólna

luke_and_leia_eps = episodes_with_luke.intersection(episodes_with_leia) 
print(f"They were both mentioned in episodes {luke_and_leia_eps}")
# Out:
# They were both mentioned in episodes {4, 5, 6, 7}

# %% [markdown]
# ### 2 zasadnicze problemy z **greppingiem**

# %% [markdown]
# ### 1. Źle wybrane wyrazy

# %%
episodes_with_motivator = docs_with_query_word("motivator", sw_words)
print(f"Episodes with 'motivartor': {episodes_with_motivator}")
# Out:
# Episodes with 'motivartor': {5}

# %% [markdown]
# ### Chyba jest dobrze ...
# <br>
#
# ![Fragment części 5](dataset/images/motivator_ep_5.png)
#
# **Fragment *Gwiezdnych Wojen* - części 5**

# %% [markdown]
# ### ... albo jednak nie
#
# ![fragment_ep_4](dataset/images/motivator_ep_4.png)
#
# **Fragment *Gwiezdnych Wojen* - części 4**  - nieznalezione przez naszą wyszukiwarkę

# %% [markdown]
# Nasz algorytm posiada **wysoki precision**, ale **niski recall**

# %% [markdown]
# ![precisionrecall](dataset/images/Precisionrecall.svg.png)
#
# By Walber - Own work, CC BY-SA 4.0, https://commons.wikimedia.org/w/index.php?curid=36926283

# %% [markdown]
# ### Rozwiązanie - odpowiednia *tokenizacja* i *lematyzacja*
#
# **tokenizacja** - podział tekst na słowa tak, by zachować ich znaczenia ("and." => "and", "\lightsabers..." => "lightsabers")
#
# **lematyzacja** - pozbycie się końcówek fleksyjnych ("lightsabers" => "lightsaber")
#
# Wówczas wszsytkie zapytania również nalezy stokenizować i zlematyzować.
#
# Dalej będziemy używać jedynie lematyzacji.

# %%
# !python -m spacy download en

import spacy
def lematize_document(path, nlp):
    with open(path, "r", encoding="UTF-8") as file:
        text = file.read()
    tokens = nlp(text)
    tokens = list(filter(lambda token: not (token.is_punct or token.is_space), tokens))
    
    for token in tokens:
        print(f"Token: {token.text:15} Lemma: {token.lemma_}") 
    
    lemmas = list(map(lambda token: token.lemma_, tokens))
    return lemmas

# %%
#prezentacja    
nlp = spacy.load('en_core_web_sm')
lematize_document(sw_scripts / "1Script_Star Wars_ The Phantom Menace.txt", nlp)
# Out:
# Token: Star            Lemma: Star
# Token: Wars            Lemma: war
# Token: Episode         Lemma: episode
# Token: 1               Lemma: 1
# Token: The             Lemma: the
# Token: Phantom         Lemma: Phantom
# Token: Menace          Lemma: Menace
# Token: TITLE           Lemma: TITLE
# Token: CARD            Lemma: card
# Token: A               Lemma: a
# Token: long            Lemma: long
# Token: time            Lemma: time
# Token: ago             Lemma: ago
# Token: in              Lemma: in
# Token: a               Lemma: a
# Token: galaxy          Lemma: galaxy
# Token: far             Lemma: far
# Token: far             Lemma: far
# Token: away            Lemma: away
# Token: A               Lemma: a
# Token: vast            Lemma: vast
# Token: sea             Lemma: sea
# Token: of              Lemma: of
# Token: stars           Lemma: star
# Token: serves          Lemma: serve
# Token: as              Lemma: as
# Token: the             Lemma: the
# Token: backdrop        Lemma: backdrop
# Token: for             Lemma: for
# Token: the             Lemma: the
# Token: main            Lemma: main
# Token: title           Lemma: title
# Token: followed        Lemma: follow
# Token: by              Lemma: by
# Token: a               Lemma: a
# Token: roll            Lemma: roll
# Token: up              Lemma: up
# Token: which           Lemma: which
# Token: crawls          Lemma: crawl
# Token: up              Lemma: up
# Token: into            Lemma: into
# Token: infinity        Lemma: infinity
# Token: EPISODE         Lemma: EPISODE
# Token: 1               Lemma: 1
# Token: THE             Lemma: the
# Token: PHANTOM         Lemma: phantom
# Token: MENACE          Lemma: MENACE
# Token: Turmoil         Lemma: Turmoil
# Token: has             Lemma: have
# Token: engulfed        Lemma: engulf
# Token: the             Lemma: the
# Token: Galactic        Lemma: Galactic
# Token: Republic        Lemma: Republic
# Token: The             Lemma: the
# Token: taxation        Lemma: taxation
# Token: of              Lemma: of
# Token: trade           Lemma: trade
# Token: routes          Lemma: route
# Token: to              Lemma: to
# Token: outlaying       Lemma: outlaye
# Token: star            Lemma: star
# Token: systems         Lemma: system
# Token: is              Lemma: be
# Token: in              Lemma: in
# Token: dispute         Lemma: dispute
# Token: Hoping          Lemma: hope
# Token: to              Lemma: to
# Token: resolve         Lemma: resolve
# Token: the             Lemma: the
# Token: matter          Lemma: matter
# Token: with            Lemma: with
# Token: a               Lemma: a
# Token: blockade        Lemma: blockade
# Token: of              Lemma: of
# Token: deadly          Lemma: deadly
# Token: battleships     Lemma: battleship
# Token: the             Lemma: the
# Token: greedy          Lemma: greedy
# Token: Trade           Lemma: Trade
# Token: Federation      Lemma: Federation
# Token: has             Lemma: have
# Token: stopped         Lemma: stop
# Token: all             Lemma: all
# Token: shipping        Lemma: ship
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: small           Lemma: small
# Token: planet          Lemma: planet
# Token: of              Lemma: of
# Token: Naboo           Lemma: Naboo
# Token: While           Lemma: while
# Token: the             Lemma: the
# Token: congress        Lemma: congress
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: Republic        Lemma: Republic
# Token: endlessly       Lemma: endlessly
# Token: debates         Lemma: debate
# Token: this            Lemma: this
# Token: alarming        Lemma: alarming
# Token: chain           Lemma: chain
# Token: of              Lemma: of
# Token: events          Lemma: event
# Token: the             Lemma: the
# Token: Supreme         Lemma: Supreme
# Token: Chancellor      Lemma: Chancellor
# Token: has             Lemma: have
# Token: secretly        Lemma: secretly
# Token: dispatched      Lemma: dispatch
# Token: two             Lemma: two
# Token: Jedi            Lemma: Jedi
# Token: Knights         Lemma: Knights
# Token: the             Lemma: the
# Token: guardians       Lemma: guardian
# Token: of              Lemma: of
# Token: peace           Lemma: peace
# Token: and             Lemma: and
# Token: justice         Lemma: justice
# Token: in              Lemma: in
# Token: the             Lemma: the
# Token: galaxy          Lemma: galaxy
# Token: to              Lemma: to
# Token: settle          Lemma: settle
# Token: the             Lemma: the
# Token: conflict        Lemma: conflict
# Token: PAN             Lemma: PAN
# Token: DOWN            Lemma: down
# Token: to              Lemma: to
# Token: reveal          Lemma: reveal
# Token: a               Lemma: a
# Token: small           Lemma: small
# Token: space           Lemma: space
# Token: cruiser         Lemma: cruiser
# Token: heading         Lemma: head
# Token: TOWARD          Lemma: toward
# Token: CAMERA          Lemma: CAMERA
# Token: at              Lemma: at
# Token: great           Lemma: great
# Token: speed           Lemma: speed
# Token: PAN             Lemma: PAN
# Token: with            Lemma: with
# Token: the             Lemma: the
# Token: cruiser         Lemma: cruiser
# Token: as              Lemma: as
# Token: it              Lemma: it
# Token: heads           Lemma: head
# Token: towardthe       Lemma: towardthe
# Token: beautiful       Lemma: beautiful
# Token: green           Lemma: green
# Token: planet          Lemma: planet
# Token: of              Lemma: of
# Token: Naboo           Lemma: Naboo
# Token: which           Lemma: which
# Token: is              Lemma: be
# Token: surrounded      Lemma: surround
# Token: by              Lemma: by
# Token: hundreds        Lemma: hundred
# Token: of              Lemma: of
# Token: Trade           Lemma: Trade
# Token: Federation      Lemma: Federation
# Token: battleships     Lemma: battleship
# Token: INT             Lemma: INT
# Token: REPUBLIC        Lemma: REPUBLIC
# Token: CRUISER         Lemma: CRUISER
# Token: COCKPIT         Lemma: COCKPIT
# Token: In              Lemma: in
# Token: the             Lemma: the
# Token: cockpit         Lemma: cockpit
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: cruise          Lemma: cruise
# Token: the             Lemma: the
# Token: CAPTAIN         Lemma: CAPTAIN
# Token: and             Lemma: and
# Token: PILOT           Lemma: pilot
# Token: maneuver        Lemma: maneuver
# Token: closer          Lemma: close
# Token: to              Lemma: to
# Token: one             Lemma: one
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: battleships     Lemma: battleship
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: off             Lemma: off
# Token: screen          Lemma: screen
# Token: voice           Lemma: voice
# Token: Captain         Lemma: captain
# Token: The             Lemma: the
# Token: Captain         Lemma: Captain
# Token: turns           Lemma: turn
# Token: to              Lemma: to
# Token: an              Lemma: an
# Token: unseen          Lemma: unseen
# Token: figure          Lemma: figure
# Token: sitting         Lemma: sit
# Token: behind          Lemma: behind
# Token: her             Lemma: she
# Token: CAPTAIN         Lemma: captain
# Token: Yes             Lemma: yes
# Token: sir             Lemma: sir
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: V.O             Lemma: V.O
# Token: Tell            Lemma: tell
# Token: them            Lemma: they
# Token: we              Lemma: we
# Token: wish            Lemma: wish
# Token: to              Lemma: to
# Token: board           Lemma: board
# Token: at              Lemma: at
# Token: once            Lemma: once
# Token: CAPTAIN         Lemma: captain
# Token: Yes             Lemma: yes
# Token: sir             Lemma: sir
# Token: The             Lemma: the
# Token: CAPTAIN         Lemma: CAPTAIN
# Token: looks           Lemma: look
# Token: to              Lemma: to
# Token: her             Lemma: her
# Token: view            Lemma: view
# Token: screen          Lemma: screen
# Token: where           Lemma: where
# Token: NUTE            Lemma: nute
# Token: GUNRAY          Lemma: GUNRAY
# Token: a               Lemma: a
# Token: Neimoidian      Lemma: neimoidian
# Token: trade           Lemma: trade
# Token: viceroy         Lemma: viceroy
# Token: waits           Lemma: wait
# Token: for             Lemma: for
# Token: a               Lemma: a
# Token: reply           Lemma: reply
# Token: CAPTAIN         Lemma: captain
# Token: cont'd          Lemma: cont'd
# Token: With            Lemma: with
# Token: all             Lemma: all
# Token: due             Lemma: due
# Token: respect         Lemma: respect
# Token: for             Lemma: for
# Token: the             Lemma: the
# Token: Trade           Lemma: Trade
# Token: Federation      Lemma: Federation
# Token: the             Lemma: the
# Token: Ambassodors     Lemma: ambassodor
# Token: for             Lemma: for
# Token: the             Lemma: the
# Token: Supreme         Lemma: Supreme
# Token: Chancellor      Lemma: Chancellor
# Token: wish            Lemma: wish
# Token: to              Lemma: to
# Token: board           Lemma: board
# Token: immediately     Lemma: immediately
# Token: NUTE            Lemma: nute
# Token: Yes             Lemma: yes
# Token: yes             Lemma: yes
# Token: of              Lemma: of
# Token: coarse          Lemma: coarse
# Token: ahhh            Lemma: ahhh
# Token: as              Lemma: as
# Token: you             Lemma: you
# Token: know            Lemma: know
# Token: our             Lemma: our
# Token: blockade        Lemma: blockade
# Token: is              Lemma: be
# Token: perfectly       Lemma: perfectly
# Token: legal           Lemma: legal
# Token: and             Lemma: and
# Token: we              Lemma: we
# Token: 'd              Lemma: 'd
# Token: be              Lemma: be
# Token: happy           Lemma: happy
# Token: to              Lemma: to
# Token: recieve         Lemma: recieve
# Token: the             Lemma: the
# Token: Ambassador      Lemma: Ambassador
# Token: Happy           Lemma: happy
# Token: to              Lemma: to
# Token: The             Lemma: the
# Token: screen          Lemma: screen
# Token: goes            Lemma: go
# Token: black           Lemma: black
# Token: Out             Lemma: out
# Token: the             Lemma: the
# Token: cockpit         Lemma: cockpit
# Token: window          Lemma: window
# Token: the             Lemma: the
# Token: sinister        Lemma: sinister
# Token: battleship      Lemma: battleship
# Token: looms           Lemma: loom
# Token: ever            Lemma: ever
# Token: closer          Lemma: close
# Token: EXT             Lemma: EXT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: DOCKING         Lemma: DOCKING
# Token: BAY             Lemma: BAY
# Token: SPACE           Lemma: SPACE
# Token: FX              Lemma: FX
# Token: The             Lemma: the
# Token: small           Lemma: small
# Token: space           Lemma: space
# Token: cruiser         Lemma: cruiser
# Token: docks           Lemma: dock
# Token: in              Lemma: in
# Token: the             Lemma: the
# Token: enormous        Lemma: enormous
# Token: main            Lemma: main
# Token: bay             Lemma: bay
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: Federation      Lemma: Federation
# Token: battleship      Lemma: battleship
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: DOCKING         Lemma: DOCKING
# Token: BAY             Lemma: BAY
# Token: SPACE           Lemma: SPACE
# Token: A               Lemma: a
# Token: PROTOCOL        Lemma: PROTOCOL
# Token: DROID           Lemma: DROID
# Token: TC-14           Lemma: TC-14
# Token: waits           Lemma: wait
# Token: at              Lemma: at
# Token: the             Lemma: the
# Token: door            Lemma: door
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: docking         Lemma: docking
# Token: bay             Lemma: bay
# Token: Two             Lemma: two
# Token: WORKER          Lemma: WORKER
# Token: DROIDS          Lemma: DROIDS
# Token: PK-4            Lemma: pk-4
# Token: and             Lemma: and
# Token: EG-9            Lemma: eg-9
# Token: watch           Lemma: watch
# Token: PK-4            Lemma: pk-4
# Token: They            Lemma: they
# Token: must            Lemma: must
# Token: be              Lemma: be
# Token: important       Lemma: important
# Token: if              Lemma: if
# Token: the             Lemma: the
# Token: Viceroy         Lemma: Viceroy
# Token: sent            Lemma: send
# Token: one             Lemma: one
# Token: of              Lemma: of
# Token: those           Lemma: those
# Token: useless         Lemma: useless
# Token: protocol        Lemma: protocol
# Token: gearheads       Lemma: gearhead
# Token: to              Lemma: to
# Token: greet           Lemma: greet
# Token: them            Lemma: they
# Token: The             Lemma: the
# Token: door            Lemma: door
# Token: opens           Lemma: open
# Token: and             Lemma: and
# Token: the             Lemma: the
# Token: Republic        Lemma: Republic
# Token: cruiser         Lemma: cruiser
# Token: can             Lemma: can
# Token: be              Lemma: be
# Token: seen            Lemma: see
# Token: in              Lemma: in
# Token: the             Lemma: the
# Token: docking         Lemma: docking
# Token: bay             Lemma: bay
# Token: Two             Lemma: two
# Token: darkly          Lemma: darkly
# Token: robed           Lemma: robed
# Token: figures         Lemma: figure
# Token: are             Lemma: be
# Token: greeted         Lemma: greet
# Token: by              Lemma: by
# Token: TC-14           Lemma: TC-14
# Token: TC-14           Lemma: tc-14
# Token: I               Lemma: I
# Token: 'm              Lemma: be
# Token: TC-14           Lemma: tc-14
# Token: at              Lemma: at
# Token: your            Lemma: your
# Token: service         Lemma: service
# Token: This            Lemma: this
# Token: way             Lemma: way
# Token: please          Lemma: please
# Token: They            Lemma: they
# Token: move            Lemma: move
# Token: off             Lemma: off
# Token: down            Lemma: down
# Token: the             Lemma: the
# Token: hallway         Lemma: hallway
# Token: EG-9            Lemma: eg-9
# Token: A               Lemma: a
# Token: Republic        Lemma: Republic
# Token: cruiser         Lemma: cruiser
# Token: That            Lemma: that
# Token: 's              Lemma: be
# Token: trouble         Lemma: trouble
# Token: don't           Lemma: don't
# Token: you             Lemma: you
# Token: think           Lemma: think
# Token: PR-4            Lemma: pr-4
# Token: I               Lemma: I
# Token: 'm              Lemma: be
# Token: not             Lemma: not
# Token: made            Lemma: make
# Token: to              Lemma: to
# Token: think           Lemma: think
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: CONFERENCE      Lemma: CONFERENCE
# Token: ROOM            Lemma: ROOM
# Token: A               Lemma: a
# Token: door            Lemma: door
# Token: slides          Lemma: slide
# Token: open            Lemma: open
# Token: and             Lemma: and
# Token: the             Lemma: the
# Token: two             Lemma: two
# Token: cloaked         Lemma: cloak
# Token: shapes          Lemma: shape
# Token: are             Lemma: be
# Token: led             Lemma: lead
# Token: PAST            Lemma: past
# Token: CAMERA          Lemma: CAMERA
# Token: into            Lemma: into
# Token: the             Lemma: the
# Token: formal          Lemma: formal
# Token: conference      Lemma: conference
# Token: room            Lemma: room
# Token: by              Lemma: by
# Token: TC-14           Lemma: TC-14
# Token: TC-14           Lemma: tc-14
# Token: I               Lemma: I
# Token: hope            Lemma: hope
# Token: you             Lemma: you
# Token: honoured        Lemma: honour
# Token: sirs            Lemma: sir
# Token: with            Lemma: with
# Token: the             Lemma: the
# Token: most            Lemma: most
# Token: comfortable     Lemma: comfortable
# Token: here            Lemma: here
# Token: My              Lemma: my
# Token: master          Lemma: master
# Token: will            Lemma: will
# Token: be              Lemma: be
# Token: with            Lemma: with
# Token: you             Lemma: you
# Token: shortly         Lemma: shortly
# Token: The             Lemma: the
# Token: droid           Lemma: droid
# Token: bows            Lemma: bow
# Token: before          Lemma: before
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: KENOBI          Lemma: KENOBI
# Token: and             Lemma: and
# Token: QUI-            Lemma: qui-
# Token: GON             Lemma: GON
# Token: JINN            Lemma: JINN
# Token: He              Lemma: he
# Token: backs           Lemma: back
# Token: out             Lemma: out
# Token: the             Lemma: the
# Token: door            Lemma: door
# Token: and             Lemma: and
# Token: it              Lemma: it
# Token: closes          Lemma: close
# Token: The             Lemma: the
# Token: JEDI            Lemma: JEDI
# Token: lower           Lemma: lower
# Token: their           Lemma: their
# Token: hoods           Lemma: hood
# Token: and             Lemma: and
# Token: look            Lemma: look
# Token: out             Lemma: out
# Token: a               Lemma: a
# Token: large           Lemma: large
# Token: window          Lemma: window
# Token: at              Lemma: at
# Token: the             Lemma: the
# Token: lush            Lemma: lush
# Token: green           Lemma: green
# Token: planet          Lemma: planet
# Token: of              Lemma: of
# Token: Naboo           Lemma: Naboo
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: sixty           Lemma: sixty
# Token: years           Lemma: year
# Token: old             Lemma: old
# Token: has             Lemma: have
# Token: long            Lemma: long
# Token: white           Lemma: white
# Token: hair            Lemma: hair
# Token: in              Lemma: in
# Token: a               Lemma: a
# Token: ponytail        Lemma: ponytail
# Token: He              Lemma: he
# Token: is              Lemma: be
# Token: tall            Lemma: tall
# Token: and             Lemma: and
# Token: striking        Lemma: striking
# Token: with            Lemma: with
# Token: blue            Lemma: blue
# Token: eyes            Lemma: eye
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: is              Lemma: be
# Token: twenty          Lemma: twenty
# Token: five            Lemma: five
# Token: with            Lemma: with
# Token: very            Lemma: very
# Token: short           Lemma: short
# Token: brown           Lemma: brown
# Token: hair            Lemma: hair
# Token: pale            Lemma: pale
# Token: skin            Lemma: skin
# Token: and             Lemma: and
# Token: blue            Lemma: blue
# Token: eyes            Lemma: eye
# Token: Several         Lemma: several
# Token: exotic          Lemma: exotic
# Token: bird            Lemma: bird
# Token: like            Lemma: like
# Token: creatures       Lemma: creature
# Token: SING            Lemma: sing
# Token: in              Lemma: in
# Token: a               Lemma: a
# Token: cage            Lemma: cage
# Token: near            Lemma: near
# Token: the             Lemma: the
# Token: door            Lemma: door
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: I               Lemma: I
# Token: have            Lemma: have
# Token: a               Lemma: a
# Token: bad             Lemma: bad
# Token: feeling         Lemma: feeling
# Token: about           Lemma: about
# Token: this            Lemma: this
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: I               Lemma: I
# Token: do              Lemma: do
# Token: n't             Lemma: n't
# Token: sense           Lemma: sense
# Token: anything        Lemma: anything
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: It              Lemma: it
# Token: 's              Lemma: be
# Token: not             Lemma: not
# Token: about           Lemma: about
# Token: the             Lemma: the
# Token: mission         Lemma: mission
# Token: Master          Lemma: Master
# Token: it              Lemma: it
# Token: 's              Lemma: be
# Token: somethging      Lemma: somethging
# Token: elsewhere       Lemma: elsewhere
# Token: elusive         Lemma: elusive
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: Do              Lemma: do
# Token: n't             Lemma: n't
# Token: center          Lemma: center
# Token: on              Lemma: on
# Token: your            Lemma: your
# Token: anxiety         Lemma: anxiety
# Token: Obi             Lemma: Obi
# Token: Wan             Lemma: Wan
# Token: Keep            Lemma: keep
# Token: your            Lemma: your
# Token: concentration   Lemma: concentration
# Token: here            Lemma: here
# Token: and             Lemma: and
# Token: now             Lemma: now
# Token: where           Lemma: where
# Token: it              Lemma: it
# Token: belongs         Lemma: belong
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: Master          Lemma: Master
# Token: Yoda            Lemma: Yoda
# Token: says            Lemma: say
# Token: I               Lemma: I
# Token: should          Lemma: should
# Token: be              Lemma: be
# Token: mindful         Lemma: mindful
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: future          Lemma: future
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: but             Lemma: but
# Token: not             Lemma: not
# Token: at              Lemma: at
# Token: the             Lemma: the
# Token: expense         Lemma: expense
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: moment          Lemma: moment
# Token: Be              Lemma: be
# Token: mindful         Lemma: mindful
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: living          Lemma: live
# Token: Force           Lemma: Force
# Token: my              Lemma: my
# Token: young           Lemma: young
# Token: Padawan         Lemma: Padawan
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: Yes             Lemma: yes
# Token: Master          Lemma: Master
# Token: how             Lemma: how
# Token: do              Lemma: do
# Token: you             Lemma: you
# Token: think           Lemma: think
# Token: the             Lemma: the
# Token: trade           Lemma: trade
# Token: viceroy         Lemma: viceroy
# Token: will            Lemma: will
# Token: deal            Lemma: deal
# Token: with            Lemma: with
# Token: the             Lemma: the
# Token: chancellor      Lemma: chancellor
# Token: 's              Lemma: 's
# Token: demands         Lemma: demand
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: These           Lemma: these
# Token: Federation      Lemma: Federation
# Token: types           Lemma: type
# Token: are             Lemma: be
# Token: cowards         Lemma: coward
# Token: The             Lemma: the
# Token: negotiations    Lemma: negotiation
# Token: will            Lemma: will
# Token: be              Lemma: be
# Token: short           Lemma: short
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: BRIDGE          Lemma: BRIDGE
# Token: NUTE            Lemma: nute
# Token: GUNRAY          Lemma: GUNRAY
# Token: and             Lemma: and
# Token: DAULTRAY        Lemma: DAULTRAY
# Token: DOFINE          Lemma: DOFINE
# Token: stand           Lemma: stand
# Token: stunned         Lemma: stunned
# Token: before          Lemma: before
# Token: TC-14           Lemma: TC-14
# Token: NUTE            Lemma: NUTE
# Token: shaken          Lemma: shake
# Token: What            Lemma: what
# Token: What            Lemma: what
# Token: did             Lemma: do
# Token: you             Lemma: you
# Token: say             Lemma: say
# Token: TC-14           Lemma: tc-14
# Token: The             Lemma: the
# Token: Ambassadors     Lemma: Ambassadors
# Token: are             Lemma: be
# Token: Jedi            Lemma: Jedi
# Token: Knights         Lemma: Knights
# Token: I               Lemma: I
# Token: believe         Lemma: believe
# Token: DOFINE          Lemma: DOFINE
# Token: I               Lemma: I
# Token: knew            Lemma: know
# Token: it              Lemma: it
# Token: They            Lemma: they
# Token: were            Lemma: be
# Token: sent            Lemma: send
# Token: to              Lemma: to
# Token: force           Lemma: force
# Token: a               Lemma: a
# Token: settlement      Lemma: settlement
# Token: eh              Lemma: eh
# Token: Blind           Lemma: blind
# Token: me              Lemma: I
# Token: we              Lemma: we
# Token: 're             Lemma: be
# Token: done            Lemma: do
# Token: for             Lemma: for
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: HALLWAY         Lemma: HALLWAY
# Token: A               Lemma: a
# Token: hologram        Lemma: hologram
# Token: of              Lemma: of
# Token: NUTE            Lemma: NUTE
# Token: surrounded      Lemma: surround
# Token: by              Lemma: by
# Token: BATTLE          Lemma: BATTLE
# Token: DROIDS          Lemma: DROIDS
# Token: appears         Lemma: appear
# Token: in              Lemma: in
# Token: the             Lemma: the
# Token: conference      Lemma: conference
# Token: room            Lemma: room
# Token: hallway         Lemma: hallway
# Token: NUTE            Lemma: NUTE
# Token: They            Lemma: they
# Token: must            Lemma: must
# Token: be              Lemma: be
# Token: dead            Lemma: dead
# Token: by              Lemma: by
# Token: now             Lemma: now
# Token: Blast           Lemma: blast
# Token: what            Lemma: what
# Token: 's              Lemma: be
# Token: left            Lemma: leave
# Token: of              Lemma: of
# Token: them            Lemma: they
# Token: The             Lemma: the
# Token: hologram        Lemma: hologram
# Token: fades           Lemma: fade
# Token: off             Lemma: off
# Token: as              Lemma: as
# Token: a               Lemma: a
# Token: BATTLE          Lemma: BATTLE
# Token: DROID           Lemma: DROID
# Token: OWO-1           Lemma: OWO-1
# Token: cautiously      Lemma: cautiously
# Token: opens           Lemma: open
# Token: the             Lemma: the
# Token: door            Lemma: door
# Token: A               Lemma: a
# Token: deadly          Lemma: deadly
# Token: green           Lemma: green
# Token: cloud           Lemma: cloud
# Token: billows         Lemma: billow
# Token: from            Lemma: from
# Token: the             Lemma: the
# Token: room            Lemma: room
# Token: BATTLE          Lemma: BATTLE
# Token: DROIDS          Lemma: DROIDS
# Token: cock            Lemma: cock
# Token: their           Lemma: their
# Token: weapons         Lemma: weapon
# Token: as              Lemma: as
# Token: a               Lemma: a
# Token: figure          Lemma: figure
# Token: stumbles        Lemma: stumble
# Token: out             Lemma: out
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: smoke           Lemma: smoke
# Token: It              Lemma: it
# Token: is              Lemma: be
# Token: TC-14           Lemma: TC-14
# Token: carrying        Lemma: carry
# Token: the             Lemma: the
# Token: tray            Lemma: tray
# Token: of              Lemma: of
# Token: drinks          Lemma: drink
# Token: TC14            Lemma: TC14
# Token: Oh              Lemma: oh
# Token: excuse          Lemma: excuse
# Token: me              Lemma: I
# Token: so              Lemma: so
# Token: sorry           Lemma: sorry
# Token: The             Lemma: the
# Token: PROTOCOL        Lemma: PROTOCOL
# Token: DROID           Lemma: DROID
# Token: passes          Lemma: pass
# Token: the             Lemma: the
# Token: armed           Lemma: armed
# Token: camp            Lemma: camp
# Token: just            Lemma: just
# Token: as              Lemma: as
# Token: two             Lemma: two
# Token: flashing        Lemma: flash
# Token: laser           Lemma: laser
# Token: swords          Lemma: sword
# Token: fly             Lemma: fly
# Token: out             Lemma: out
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: deadly          Lemma: deadly
# Token: fog             Lemma: fog
# Token: cutting         Lemma: cut
# Token: down            Lemma: down
# Token: several         Lemma: several
# Token: BATTLE          Lemma: BATTLE
# Token: DROIDS          Lemma: DROIDS
# Token: before          Lemma: before
# Token: they            Lemma: they
# Token: can             Lemma: can
# Token: fire            Lemma: fire
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: BRIDGE          Lemma: BRIDGE
# Token: The             Lemma: the
# Token: bridge          Lemma: bridge
# Token: is              Lemma: be
# Token: a               Lemma: a
# Token: cocophony       Lemma: cocophony
# Token: of              Lemma: of
# Token: alarms          Lemma: alarm
# Token: NUTE            Lemma: nute
# Token: and             Lemma: and
# Token: RUNE            Lemma: RUNE
# Token: watch           Lemma: watch
# Token: OWO-1           Lemma: OWO-1
# Token: on              Lemma: on
# Token: the             Lemma: the
# Token: viewscreen      Lemma: viewscreen
# Token: OWO-1           Lemma: owo-1
# Token: Not             Lemma: not
# Token: sure            Lemma: sure
# Token: exactly         Lemma: exactly
# Token: what            Lemma: what
# Token: OWO-1           Lemma: OWO-1
# Token: is              Lemma: be
# Token: suddenly        Lemma: suddenly
# Token: cut             Lemma: cut
# Token: in              Lemma: in
# Token: half            Lemma: half
# Token: in              Lemma: in
# Token: mid             Lemma: mid
# Token: sentence        Lemma: sentence
# Token: RUNE            Lemma: RUNE
# Token: gives           Lemma: give
# Token: NUTE            Lemma: NUTE
# Token: a               Lemma: a
# Token: worried         Lemma: worried
# Token: look            Lemma: look
# Token: NUTE            Lemma: NUTE
# Token: What            Lemma: what
# Token: in              Lemma: in
# Token: blazes          Lemma: blaze
# Token: is              Lemma: be
# Token: going           Lemma: go
# Token: on              Lemma: on
# Token: down            Lemma: down
# Token: there           Lemma: there
# Token: RUNE            Lemma: RUNE
# Token: Have            Lemma: have
# Token: you             Lemma: you
# Token: ever            Lemma: ever
# Token: encountered     Lemma: encounter
# Token: a               Lemma: a
# Token: Jedi            Lemma: Jedi
# Token: Knight          Lemma: Knight
# Token: before          Lemma: before
# Token: sir             Lemma: sir
# Token: NUTE            Lemma: nute
# Token: Well            Lemma: well
# Token: not             Lemma: not
# Token: exactly         Lemma: exactly
# Token: but             Lemma: but
# Token: I               Lemma: I
# Token: don't           Lemma: don't
# Token: (panicked       Lemma: (panicked
# Token: Seal            Lemma: seal
# Token: off             Lemma: off
# Token: the             Lemma: the
# Token: bridge          Lemma: bridge
# Token: RUNE            Lemma: RUNE
# Token: That            Lemma: that
# Token: wo              Lemma: wo
# Token: n't             Lemma: n't
# Token: be              Lemma: be
# Token: enough          Lemma: enough
# Token: sir             Lemma: sir
# Token: The             Lemma: the
# Token: doors           Lemma: door
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: bridge          Lemma: bridge
# Token: SLAM            Lemma: SLAM
# Token: shut            Lemma: shut
# Token: NUTE            Lemma: NUTE
# Token: I               Lemma: I
# Token: want            Lemma: want
# Token: destroyer       Lemma: destroyer
# Token: droids          Lemma: droid
# Token: up              Lemma: up
# Token: here            Lemma: here
# Token: at              Lemma: at
# Token: once            Lemma: once
# Token: RUNE            Lemma: RUNE
# Token: We              Lemma: we
# Token: will            Lemma: will
# Token: not             Lemma: not
# Token: survive         Lemma: survive
# Token: this            Lemma: this
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: HALLWAY         Lemma: HALLWAY
# Token: OUTSIDE         Lemma: OUTSIDE
# Token: BRIDGE          Lemma: BRIDGE
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: cuts            Lemma: cut
# Token: several         Lemma: several
# Token: BATTLE          Lemma: BATTLE
# Token: DROIDS          Lemma: DROIDS
# Token: in              Lemma: in
# Token: half            Lemma: half
# Token: creating        Lemma: create
# Token: a               Lemma: a
# Token: shower          Lemma: shower
# Token: of              Lemma: of
# Token: sparks          Lemma: spark
# Token: and             Lemma: and
# Token: metal           Lemma: metal
# Token: parts           Lemma: part
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: raises          Lemma: raise
# Token: his             Lemma: his
# Token: hand            Lemma: hand
# Token: sending         Lemma: send
# Token: several         Lemma: several
# Token: BATTLE          Lemma: BATTLE
# Token: DROIDS          Lemma: DROIDS
# Token: crashing        Lemma: crash
# Token: into            Lemma: into
# Token: the             Lemma: the
# Token: wall            Lemma: wall
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: makes           Lemma: make
# Token: his             Lemma: his
# Token: way             Lemma: way
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: bridge          Lemma: bridge
# Token: door            Lemma: door
# Token: and             Lemma: and
# Token: begins          Lemma: begin
# Token: to              Lemma: to
# Token: cut             Lemma: cut
# Token: through         Lemma: through
# Token: it              Lemma: it
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: BRIDGE          Lemma: BRIDGE
# Token: The             Lemma: the
# Token: CREW            Lemma: CREW
# Token: is              Lemma: be
# Token: very            Lemma: very
# Token: nervous         Lemma: nervous
# Token: as              Lemma: as
# Token: sparks          Lemma: spark
# Token: start           Lemma: start
# Token: flying          Lemma: fly
# Token: around          Lemma: around
# Token: the             Lemma: the
# Token: bridge          Lemma: bridge
# Token: door            Lemma: door
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: and             Lemma: and
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: are             Lemma: be
# Token: on              Lemma: on
# Token: the             Lemma: the
# Token: view            Lemma: view
# Token: screen          Lemma: screen
# Token: NUTE            Lemma: NUTE
# Token: Close           Lemma: close
# Token: the             Lemma: the
# Token: blast           Lemma: blast
# Token: doors           Lemma: door
# Token: The             Lemma: the
# Token: huge            Lemma: huge
# Token: very            Lemma: very
# Token: thick           Lemma: thick
# Token: blast           Lemma: blast
# Token: door            Lemma: door
# Token: slams           Lemma: slam
# Token: shut            Lemma: shut
# Token: followed        Lemma: follow
# Token: by              Lemma: by
# Token: a               Lemma: a
# Token: second          Lemma: second
# Token: door            Lemma: door
# Token: then            Lemma: then
# Token: a               Lemma: a
# Token: third           Lemma: third
# Token: There           Lemma: there
# Token: is              Lemma: be
# Token: a               Lemma: a
# Token: hissing         Lemma: hiss
# Token: sound           Lemma: sound
# Token: as              Lemma: as
# Token: the             Lemma: the
# Token: huge            Lemma: huge
# Token: doors           Lemma: door
# Token: seal            Lemma: seal
# Token: shut            Lemma: shut
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: tabs            Lemma: tab
# Token: the             Lemma: the
# Token: door            Lemma: door
# Token: with            Lemma: with
# Token: his             Lemma: his
# Token: sword           Lemma: sword
# Token: The             Lemma: the
# Token: screen          Lemma: screen
# Token: goes            Lemma: go
# Token: black           Lemma: black
# Token: as              Lemma: as
# Token: a               Lemma: a
# Token: red             Lemma: red
# Token: spot            Lemma: spot
# Token: appears         Lemma: appear
# Token: in              Lemma: in
# Token: the             Lemma: the
# Token: center          Lemma: center
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: blast           Lemma: blast
# Token: door            Lemma: door
# Token: RUNE            Lemma: RUNE
# Token: They            Lemma: they
# Token: 're             Lemma: be
# Token: still           Lemma: still
# Token: coming          Lemma: come
# Token: through         Lemma: through
# Token: On              Lemma: on
# Token: the             Lemma: the
# Token: door            Lemma: door
# Token: chunks          Lemma: chunk
# Token: of              Lemma: of
# Token: molten          Lemma: molten
# Token: metal           Lemma: metal
# Token: begin           Lemma: begin
# Token: to              Lemma: to
# Token: drop            Lemma: drop
# Token: away            Lemma: away
# Token: NUTE            Lemma: nute
# Token: Impossible      Lemma: impossible
# Token: This            Lemma: this
# Token: is              Lemma: be
# Token: impossible      Lemma: impossible
# Token: RUNE            Lemma: RUNE
# Token: Where           Lemma: where
# Token: are             Lemma: be
# Token: those           Lemma: those
# Token: destroyer       Lemma: destroyer
# Token: droids          Lemma: droid
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: HALLWAY         Lemma: HALLWAY
# Token: OUTSIDE         Lemma: OUTSIDE
# Token: BRIDGE          Lemma: BRIDGE
# Token: Ten             Lemma: ten
# Token: ugly            Lemma: ugly
# Token: destroyer       Lemma: destroyer
# Token: WHEEL           Lemma: WHEEL
# Token: DROIDS          Lemma: DROIDS
# Token: roll            Lemma: roll
# Token: down            Lemma: down
# Token: the             Lemma: the
# Token: hallway         Lemma: hallway
# Token: at              Lemma: at
# Token: full            Lemma: full
# Token: speed           Lemma: speed
# Token: Just            Lemma: just
# Token: before          Lemma: before
# Token: they            Lemma: they
# Token: get             Lemma: get
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: bridge          Lemma: bridge
# Token: area            Lemma: area
# Token: they            Lemma: they
# Token: stop            Lemma: stop
# Token: and             Lemma: and
# Token: transform       Lemma: transform
# Token: into            Lemma: into
# Token: their           Lemma: their
# Token: battle          Lemma: battle
# Token: configuration   Lemma: configuration
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: ca              Lemma: ca
# Token: n't             Lemma: n't
# Token: see             Lemma: see
# Token: them            Lemma: they
# Token: but             Lemma: but
# Token: senses          Lemma: sense
# Token: their           Lemma: their
# Token: presence        Lemma: presence
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: Destroyer       Lemma: destroyer
# Token: droids          Lemma: droid
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: Offhand         Lemma: Offhand
# Token: I               Lemma: I
# Token: 'd              Lemma: 'd
# Token: say             Lemma: say
# Token: this            Lemma: this
# Token: mission         Lemma: mission
# Token: is              Lemma: be
# Token: past            Lemma: past
# Token: the             Lemma: the
# Token: negotiaion      Lemma: negotiaion
# Token: stage           Lemma: stage
# Token: The             Lemma: the
# Token: WHEEL           Lemma: WHEEL
# Token: DROIDS          Lemma: DROIDS
# Token: led             Lemma: lead
# Token: by              Lemma: by
# Token: P-59            Lemma: p-59
# Token: rush            Lemma: rush
# Token: the             Lemma: the
# Token: entry           Lemma: entry
# Token: area            Lemma: area
# Token: from            Lemma: from
# Token: three           Lemma: three
# Token: hallways        Lemma: hallway
# Token: blasting        Lemma: blast
# Token: away            Lemma: away
# Token: with            Lemma: with
# Token: their           Lemma: their
# Token: laser           Lemma: laser
# Token: guns            Lemma: gun
# Token: They            Lemma: they
# Token: stop            Lemma: stop
# Token: firing          Lemma: fire
# Token: and             Lemma: and
# Token: stand           Lemma: stand
# Token: in              Lemma: in
# Token: a               Lemma: a
# Token: semi            Lemma: semi
# Token: circle          Lemma: circle
# Token: as              Lemma: as
# Token: the             Lemma: the
# Token: smoke           Lemma: smoke
# Token: clears          Lemma: clear
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: and             Lemma: and
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: are             Lemma: be
# Token: nowhere         Lemma: nowhere
# Token: to              Lemma: to
# Token: be              Lemma: be
# Token: seen            Lemma: see
# Token: P-59            Lemma: p-59
# Token: Switch          Lemma: switch
# Token: to              Lemma: to
# Token: bio             Lemma: bio
# Token: There           Lemma: there
# Token: they            Lemma: they
# Token: are             Lemma: be
# Token: The             Lemma: the
# Token: Jedi            Lemma: Jedi
# Token: materialize     Lemma: materialize
# Token: at              Lemma: at
# Token: the             Lemma: the
# Token: far             Lemma: far
# Token: end             Lemma: end
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: hallway         Lemma: hallway
# Token: and             Lemma: and
# Token: dash            Lemma: dash
# Token: through         Lemma: through
# Token: the             Lemma: the
# Token: doorway         Lemma: doorway
# Token: that            Lemma: that
# Token: slams           Lemma: slam
# Token: shut            Lemma: shut
# Token: The             Lemma: the
# Token: WHEEL           Lemma: WHEEL
# Token: DROIDS          Lemma: DROIDS
# Token: blast           Lemma: blast
# Token: away            Lemma: away
# Token: at              Lemma: at
# Token: the             Lemma: the
# Token: two             Lemma: two
# Token: JEDI            Lemma: jedi
# Token: with            Lemma: with
# Token: their           Lemma: their
# Token: laser           Lemma: laser
# Token: swords          Lemma: sword
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: They            Lemma: they
# Token: have            Lemma: have
# Token: shield          Lemma: shield
# Token: generators      Lemma: generator
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: It              Lemma: it
# Token: 's              Lemma: be
# Token: a               Lemma: a
# Token: standoff        Lemma: standoff
# Token: Let             Lemma: let
# Token: 's              Lemma: 's
# Token: go              Lemma: go
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: BRIDGE          Lemma: BRIDGE
# Token: NUTE            Lemma: nute
# Token: and             Lemma: and
# Token: RUNE            Lemma: RUNE
# Token: stand           Lemma: stand
# Token: on              Lemma: on
# Token: the             Lemma: the
# Token: bridge          Lemma: bridge
# Token: watching        Lemma: watch
# Token: the             Lemma: the
# Token: view            Lemma: view
# Token: screen          Lemma: screen
# Token: as              Lemma: as
# Token: the             Lemma: the
# Token: WHEEL           Lemma: WHEEL
# Token: DROIDS          Lemma: DROIDS
# Token: POV             Lemma: POV
# Token: speeds          Lemma: speed
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: doorway         Lemma: doorway
# Token: RUNE            Lemma: RUNE
# Token: We              Lemma: we
# Token: have            Lemma: have
# Token: them            Lemma: they
# Token: on              Lemma: on
# Token: the             Lemma: the
# Token: run             Lemma: run
# Token: sir             Lemma: sir
# Token: they're         Lemma: they're
# Token: no              Lemma: no
# Token: match           Lemma: match
# Token: for             Lemma: for
# Token: destroyer       Lemma: destroyer
# Token: droids          Lemma: droid
# Token: TEY             Lemma: TEY
# Token: HOW             Lemma: HOW
# Token: Sir             Lemma: Sir
# Token: they            Lemma: they
# Token: 've             Lemma: 've
# Token: gone            Lemma: go
# Token: up              Lemma: up
# Token: the             Lemma: the
# Token: ventilation     Lemma: ventilation
# Token: shaft           Lemma: shaft
# Token: INT             Lemma: INT
# Token: FEDERATION      Lemma: FEDERATION
# Token: BATTLESHIP      Lemma: BATTLESHIP
# Token: MAIN            Lemma: MAIN
# Token: BAY             Lemma: BAY
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: and             Lemma: and
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: appear          Lemma: appear
# Token: at              Lemma: at
# Token: a               Lemma: a
# Token: large           Lemma: large
# Token: vent            Lemma: vent
# Token: in              Lemma: in
# Token: a               Lemma: a
# Token: giant           Lemma: giant
# Token: hanger          Lemma: hanger
# Token: bay             Lemma: bay
# Token: They            Lemma: they
# Token: are             Lemma: be
# Token: careful         Lemma: careful
# Token: not             Lemma: not
# Token: to              Lemma: to
# Token: be              Lemma: be
# Token: seen            Lemma: see
# Token: Thousands       Lemma: thousand
# Token: of              Lemma: of
# Token: BATTLE          Lemma: BATTLE
# Token: DROIDS          Lemma: DROIDS
# Token: are             Lemma: be
# Token: loading         Lemma: load
# Token: onto            Lemma: onto
# Token: landing         Lemma: landing
# Token: craft           Lemma: craft
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: Battle          Lemma: battle
# Token: droids          Lemma: droid
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: It              Lemma: it
# Token: 's              Lemma: be
# Token: an              Lemma: an
# Token: invisible       Lemma: invisible
# Token: army            Lemma: army
# Token: QUI             Lemma: QUI
# Token: GON             Lemma: GON
# Token: It              Lemma: it
# Token: 's              Lemma: be
# Token: an              Lemma: an
# Token: odd             Lemma: odd
# Token: play            Lemma: play
# Token: for             Lemma: for
# Token: the             Lemma: the
# Token: Trade           Lemma: Trade
# Token: Federation      Lemma: Federation
# Token: We              Lemma: we
# Token: 've             Lemma: 've
# Token: got             Lemma: get
# Token: to              Lemma: to
# Token: warn            Lemma: warn
# Token: the             Lemma: the
# Token: Naboo           Lemma: Naboo
# Token: and             Lemma: and
# Token: contact         Lemma: contact
# Token: Chancellor      Lemma: Chancellor
# Token: Valorum         Lemma: Valorum
# Token: Let             Lemma: let
# Token: 's              Lemma: 's
# Token: split           Lemma: split
# Token: up              Lemma: up
# Token: Stow            Lemma: stow
# Token: aboard          Lemma: aboard
# Token: separate        Lemma: separate
# Token: ships           Lemma: ship
# Token: and             Lemma: and
# Token: meet            Lemma: meet
# Token: down            Lemma: down
# Token: on              Lemma: on
# Token: the             Lemma: the
# Token: planet          Lemma: planet
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: You             Lemma: you
# Token: were            Lemma: be
# Token: right           Lemma: right
# Token: about           Lemma: about
# Token: one             Lemma: one
# Token: thing           Lemma: thing
# Token: Master          Lemma: Master
# Token: The             Lemma: the
# Token: negotiations    Lemma: negotiation
# Token: were            Lemma: be
# ...
# Token: go              Lemma: go
# Token: ANAKIN          Lemma: ANAKIN
# Token: What            Lemma: what
# Token: will            Lemma: will
# Token: happen          Lemma: happen
# Token: to              Lemma: to
# Token: me              Lemma: I
# Token: now             Lemma: now
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: I               Lemma: I
# Token: am              Lemma: be
# Token: your            Lemma: your
# Token: Master          Lemma: Master
# Token: now             Lemma: now
# Token: You             Lemma: you
# Token: will            Lemma: will
# Token: become          Lemma: become
# Token: a               Lemma: a
# Token: Jedi            Lemma: Jedi
# Token: I               Lemma: I
# Token: promise         Lemma: promise
# Token: To              Lemma: to
# Token: one             Lemma: one
# Token: side            Lemma: side
# Token: MACE            Lemma: MACE
# Token: WINDU           Lemma: WINDU
# Token: turns           Lemma: turn
# Token: to              Lemma: to
# Token: YODA            Lemma: YODA
# Token: MACE            Lemma: MACE
# Token: WINDU           Lemma: WINDU
# Token: There           Lemma: there
# Token: is              Lemma: be
# Token: no              Lemma: no
# Token: doubt           Lemma: doubt
# Token: The             Lemma: the
# Token: mysterious      Lemma: mysterious
# Token: warrior         Lemma: warrior
# Token: was             Lemma: be
# Token: a               Lemma: a
# Token: Sith            Lemma: Sith
# Token: YODA            Lemma: YODA
# Token: Always          Lemma: always
# Token: two             Lemma: two
# Token: there           Lemma: there
# Token: are             Lemma: be
# Token: no              Lemma: no
# Token: more            Lemma: more
# Token: no              Lemma: no
# Token: less            Lemma: less
# Token: A               Lemma: a
# Token: maste           Lemma: maste
# Token: and             Lemma: and
# Token: an              Lemma: an
# Token: apprentice      Lemma: apprentice
# Token: MACE            Lemma: MACE
# Token: WINDU           Lemma: WINDU
# Token: But             Lemma: but
# Token: which           Lemma: which
# Token: one             Lemma: one
# Token: was             Lemma: be
# Token: destroyed       Lemma: destroy
# Token: the             Lemma: the
# Token: master          Lemma: master
# Token: or              Lemma: or
# Token: the             Lemma: the
# Token: apprentice      Lemma: apprentice
# Token: They            Lemma: they
# Token: give            Lemma: give
# Token: each            Lemma: each
# Token: other           Lemma: other
# Token: a               Lemma: a
# Token: concerned       Lemma: concerned
# Token: look            Lemma: look
# Token: EXT             Lemma: EXT
# Token: THEED           Lemma: theed
# Token: CENTRAL         Lemma: central
# Token: PLAZA           Lemma: PLAZA
# Token: DAY             Lemma: DAY
# Token: CHILDEREN       Lemma: CHILDEREN
# Token: SING            Lemma: sing
# Token: and             Lemma: and
# Token: throw           Lemma: throw
# Token: flowers         Lemma: flower
# Token: on              Lemma: on
# Token: the             Lemma: the
# Token: passing         Lemma: pass
# Token: GUNGAN          Lemma: GUNGAN
# Token: SOLDIERS        Lemma: soldier
# Token: The             Lemma: the
# Token: CROWDS          Lemma: CROWDS
# Token: CHEER           Lemma: CHEER
# Token: It              Lemma: it
# Token: is              Lemma: be
# Token: a               Lemma: a
# Token: grand           Lemma: grand
# Token: parade          Lemma: parade
# Token: QUEEN           Lemma: QUEEN
# Token: AMIDALA         Lemma: AMIDALA
# Token: stands          Lemma: stand
# Token: next            Lemma: next
# Token: to              Lemma: to
# Token: the             Lemma: the
# Token: SUPREME         Lemma: SUPREME
# Token: CHANCELLOR      Lemma: CHANCELLOR
# Token: PALPATINE       Lemma: PALPATINE
# Token: ANAKIN          Lemma: ANAKIN
# Token: OBI             Lemma: OBI
# Token: WAN             Lemma: WAN
# Token: SIO             Lemma: SIO
# Token: BIBBLE          Lemma: BIBBLE
# Token: and             Lemma: and
# Token: the             Lemma: the
# Token: JEDI            Lemma: JEDI
# Token: COUNCIL         Lemma: COUNCIL
# Token: ARTOO           Lemma: ARTOO
# Token: stands          Lemma: stand
# Token: in              Lemma: in
# Token: front           Lemma: front
# Token: of              Lemma: of
# Token: the             Lemma: the
# Token: QUEEN           Lemma: QUEEN
# Token: 'S              Lemma: 's
# Token: HANDMAIDENS     Lemma: HANDMAIDENS
# Token: and             Lemma: and
# Token: whistles        Lemma: whistle
# Token: at              Lemma: at
# Token: the             Lemma: the
# Token: parade          Lemma: parade
# Token: QUEEN           Lemma: QUEEN
# Token: AMIDALA         Lemma: AMIDALA
# Token: and             Lemma: and
# Token: PALPATINE       Lemma: PALPATINE
# Token: smile           Lemma: smile
# Token: at              Lemma: at
# Token: one             Lemma: one
# Token: another         Lemma: another
# Token: In              Lemma: in
# Token: the             Lemma: the
# Token: parade          Lemma: parade
# Token: are             Lemma: be
# Token: BOSS            Lemma: boss
# Token: NASS            Lemma: NASS
# Token: and             Lemma: and
# Token: his             Lemma: his
# Token: GUARDS          Lemma: GUARDS
# Token: JAR             Lemma: JAR
# Token: JAR             Lemma: JAR
# Token: and             Lemma: and
# Token: GENERAL         Lemma: GENERAL
# Token: CEEL            Lemma: CEEL
# Token: The             Lemma: the
# Token: GUNGANS         Lemma: GUNGANS
# Token: ride            Lemma: ride
# Token: KAADU           Lemma: KAADU
# Token: They            Lemma: they
# Token: stop            Lemma: stop
# Token: before          Lemma: before
# Token: the             Lemma: the
# Token: QUEEN           Lemma: queen
# Token: and             Lemma: and
# Token: walk            Lemma: walk
# Token: up              Lemma: up
# Token: the             Lemma: the
# Token: steps           Lemma: step
# Token: to              Lemma: to
# Token: stand           Lemma: stand
# Token: by              Lemma: by
# Token: her             Lemma: her
# Token: side            Lemma: side
# Token: BOSS            Lemma: boss
# Token: NASS            Lemma: NASS
# Token: holds           Lemma: hold
# Token: up              Lemma: up
# Token: the             Lemma: the
# Token: Globe           Lemma: Globe
# Token: of              Lemma: of
# Token: Peace           Lemma: Peace
# Token: EVERYONE        Lemma: everyone
# Token: CHEERS          Lemma: cheer
# Token: The             Lemma: the
# Token: parade          Lemma: parade
# Token: marches         Lemma: march
# Token: on              Lemma: on
# Token: IRIS            Lemma: IRIS
# Token: OUT             Lemma: OUT
# Token: End             Lemma: end
# Token: titles          Lemma: title
# ['Star',
#  'war',
#  'episode',
#  '1',
#  'the',
#  'Phantom',
#  'Menace',
#  'TITLE',
#  'card',
#  'a',
#  'long',
#  'time',
#  'ago',
#  'in',
#  'a',
#  'galaxy',
#  'far',
#  'far',
#  'away',
#  'a',
#  'vast',
#  'sea',
#  'of',
#  'star',
#  'serve',
#  'as',
#  'the',
#  'backdrop',
#  'for',
#  'the',
#  'main',
#  'title',
#  'follow',
#  'by',
#  'a',
#  'roll',
#  'up',
#  'which',
#  'crawl',
#  'up',
#  'into',
#  'infinity',
#  'EPISODE',
#  '1',
#  'the',
#  'phantom',
#  'MENACE',
#  'Turmoil',
#  'have',
#  'engulf',
#  'the',
#  'Galactic',
#  'Republic',
#  'the',
#  'taxation',
#  'of',
#  'trade',
#  'route',
#  'to',
#  'outlaye',
#  'star',
#  'system',
#  'be',
#  'in',
#  'dispute',
#  'hope',
#  'to',
#  'resolve',
#  'the',
#  'matter',
#  'with',
#  'a',
#  'blockade',
#  'of',
#  'deadly',
#  'battleship',
#  'the',
#  'greedy',
#  'Trade',
#  'Federation',
#  'have',
#  'stop',
#  'all',
#  'ship',
#  'to',
#  'the',
#  'small',
#  'planet',
#  'of',
#  'Naboo',
#  'while',
#  'the',
#  'congress',
#  'of',
#  'the',
#  'Republic',
#  'endlessly',
#  'debate',
#  'this',
#  'alarming',
#  'chain',
#  'of',
#  'event',
#  'the',
#  'Supreme',
#  'Chancellor',
#  'have',
#  'secretly',
#  'dispatch',
#  'two',
#  'Jedi',
#  'Knights',
#  'the',
#  'guardian',
#  'of',
#  'peace',
#  'and',
#  'justice',
#  'in',
#  'the',
#  'galaxy',
#  'to',
#  'settle',
#  'the',
#  'conflict',
#  'PAN',
#  'down',
#  'to',
#  'reveal',
#  'a',
#  'small',
#  'space',
#  'cruiser',
#  'head',
#  'toward',
#  'CAMERA',
#  'at',
#  'great',
#  'speed',
#  'PAN',
#  'with',
#  'the',
#  'cruiser',
#  'as',
#  'it',
#  'head',
#  'towardthe',
#  'beautiful',
#  'green',
#  'planet',
#  'of',
#  'Naboo',
#  'which',
#  'be',
#  'surround',
#  'by',
#  'hundred',
#  'of',
#  'Trade',
#  'Federation',
#  'battleship',
#  'INT',
#  'REPUBLIC',
#  'CRUISER',
#  'COCKPIT',
#  'in',
#  'the',
#  'cockpit',
#  'of',
#  'the',
#  'cruise',
#  'the',
#  'CAPTAIN',
#  'and',
#  'pilot',
#  'maneuver',
#  'close',
#  'to',
#  'one',
#  'of',
#  'the',
#  'battleship',
#  'QUI',
#  'GON',
#  'off',
#  'screen',
#  'voice',
#  'captain',
#  'the',
#  'Captain',
#  'turn',
#  'to',
#  'an',
#  'unseen',
#  'figure',
#  'sit',
#  'behind',
#  'she',
#  'captain',
#  'yes',
#  'sir',
#  'QUI',
#  'GON',
#  'V.O',
#  'tell',
#  'they',
#  'we',
#  'wish',
#  'to',
#  'board',
#  'at',
#  'once',
#  'captain',
#  'yes',
#  'sir',
#  'the',
#  'CAPTAIN',
#  'look',
#  'to',
#  'her',
#  'view',
#  'screen',
#  'where',
#  'nute',
#  'GUNRAY',
#  'a',
#  'neimoidian',
#  'trade',
#  'viceroy',
#  'wait',
#  'for',
#  'a',
#  'reply',
#  'captain',
#  "cont'd",
#  'with',
#  'all',
#  'due',
#  'respect',
#  'for',
#  'the',
#  'Trade',
#  'Federation',
#  'the',
#  'ambassodor',
#  'for',
#  'the',
#  'Supreme',
#  'Chancellor',
#  'wish',
#  'to',
#  'board',
#  'immediately',
#  'nute',
#  'yes',
#  'yes',
#  'of',
#  'coarse',
#  'ahhh',
#  'as',
#  'you',
#  'know',
#  'our',
#  'blockade',
#  'be',
#  'perfectly',
#  'legal',
#  'and',
#  'we',
#  "'d",
#  'be',
#  'happy',
#  'to',
#  'recieve',
#  'the',
#  'Ambassador',
#  'happy',
#  'to',
#  'the',
#  'screen',
#  'go',
#  'black',
#  'out',
#  'the',
#  'cockpit',
#  'window',
#  'the',
#  'sinister',
#  'battleship',
#  'loom',
#  'ever',
#  'close',
#  'EXT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'DOCKING',
#  'BAY',
#  'SPACE',
#  'FX',
#  'the',
#  'small',
#  'space',
#  'cruiser',
#  'dock',
#  'in',
#  'the',
#  'enormous',
#  'main',
#  'bay',
#  'of',
#  'the',
#  'Federation',
#  'battleship',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'DOCKING',
#  'BAY',
#  'SPACE',
#  'a',
#  'PROTOCOL',
#  'DROID',
#  'TC-14',
#  'wait',
#  'at',
#  'the',
#  'door',
#  'to',
#  'the',
#  'docking',
#  'bay',
#  'two',
#  'WORKER',
#  'DROIDS',
#  'pk-4',
#  'and',
#  'eg-9',
#  'watch',
#  'pk-4',
#  'they',
#  'must',
#  'be',
#  'important',
#  'if',
#  'the',
#  'Viceroy',
#  'send',
#  'one',
#  'of',
#  'those',
#  'useless',
#  'protocol',
#  'gearhead',
#  'to',
#  'greet',
#  'they',
#  'the',
#  'door',
#  'open',
#  'and',
#  'the',
#  'Republic',
#  'cruiser',
#  'can',
#  'be',
#  'see',
#  'in',
#  'the',
#  'docking',
#  'bay',
#  'two',
#  'darkly',
#  'robed',
#  'figure',
#  'be',
#  'greet',
#  'by',
#  'TC-14',
#  'tc-14',
#  'I',
#  'be',
#  'tc-14',
#  'at',
#  'your',
#  'service',
#  'this',
#  'way',
#  'please',
#  'they',
#  'move',
#  'off',
#  'down',
#  'the',
#  'hallway',
#  'eg-9',
#  'a',
#  'Republic',
#  'cruiser',
#  'that',
#  'be',
#  'trouble',
#  "don't",
#  'you',
#  'think',
#  'pr-4',
#  'I',
#  'be',
#  'not',
#  'make',
#  'to',
#  'think',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'CONFERENCE',
#  'ROOM',
#  'a',
#  'door',
#  'slide',
#  'open',
#  'and',
#  'the',
#  'two',
#  'cloak',
#  'shape',
#  'be',
#  'lead',
#  'past',
#  'CAMERA',
#  'into',
#  'the',
#  'formal',
#  'conference',
#  'room',
#  'by',
#  'TC-14',
#  'tc-14',
#  'I',
#  'hope',
#  'you',
#  'honour',
#  'sir',
#  'with',
#  'the',
#  'most',
#  'comfortable',
#  'here',
#  'my',
#  'master',
#  'will',
#  'be',
#  'with',
#  'you',
#  'shortly',
#  'the',
#  'droid',
#  'bow',
#  'before',
#  'OBI',
#  'WAN',
#  'KENOBI',
#  'and',
#  'qui-',
#  'GON',
#  'JINN',
#  'he',
#  'back',
#  'out',
#  'the',
#  'door',
#  'and',
#  'it',
#  'close',
#  'the',
#  'JEDI',
#  'lower',
#  'their',
#  'hood',
#  'and',
#  'look',
#  'out',
#  'a',
#  'large',
#  'window',
#  'at',
#  'the',
#  'lush',
#  'green',
#  'planet',
#  'of',
#  'Naboo',
#  'QUI',
#  'GON',
#  'sixty',
#  'year',
#  'old',
#  'have',
#  'long',
#  'white',
#  'hair',
#  'in',
#  'a',
#  'ponytail',
#  'he',
#  'be',
#  'tall',
#  'and',
#  'striking',
#  'with',
#  'blue',
#  'eye',
#  'OBI',
#  'WAN',
#  'be',
#  'twenty',
#  'five',
#  'with',
#  'very',
#  'short',
#  'brown',
#  'hair',
#  'pale',
#  'skin',
#  'and',
#  'blue',
#  'eye',
#  'several',
#  'exotic',
#  'bird',
#  'like',
#  'creature',
#  'sing',
#  'in',
#  'a',
#  'cage',
#  'near',
#  'the',
#  'door',
#  'OBI',
#  'WAN',
#  'I',
#  'have',
#  'a',
#  'bad',
#  'feeling',
#  'about',
#  'this',
#  'QUI',
#  'GON',
#  'I',
#  'do',
#  "n't",
#  'sense',
#  'anything',
#  'OBI',
#  'WAN',
#  'it',
#  'be',
#  'not',
#  'about',
#  'the',
#  'mission',
#  'Master',
#  'it',
#  'be',
#  'somethging',
#  'elsewhere',
#  'elusive',
#  'QUI',
#  'GON',
#  'do',
#  "n't",
#  'center',
#  'on',
#  'your',
#  'anxiety',
#  'Obi',
#  'Wan',
#  'keep',
#  'your',
#  'concentration',
#  'here',
#  'and',
#  'now',
#  'where',
#  'it',
#  'belong',
#  'OBI',
#  'WAN',
#  'Master',
#  'Yoda',
#  'say',
#  'I',
#  'should',
#  'be',
#  'mindful',
#  'of',
#  'the',
#  'future',
#  'QUI',
#  'GON',
#  'but',
#  'not',
#  'at',
#  'the',
#  'expense',
#  'of',
#  'the',
#  'moment',
#  'be',
#  'mindful',
#  'of',
#  'the',
#  'live',
#  'Force',
#  'my',
#  'young',
#  'Padawan',
#  'OBI',
#  'WAN',
#  'yes',
#  'Master',
#  'how',
#  'do',
#  'you',
#  'think',
#  'the',
#  'trade',
#  'viceroy',
#  'will',
#  'deal',
#  'with',
#  'the',
#  'chancellor',
#  "'s",
#  'demand',
#  'QUI',
#  'GON',
#  'these',
#  'Federation',
#  'type',
#  'be',
#  'coward',
#  'the',
#  'negotiation',
#  'will',
#  'be',
#  'short',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'BRIDGE',
#  'nute',
#  'GUNRAY',
#  'and',
#  'DAULTRAY',
#  'DOFINE',
#  'stand',
#  'stunned',
#  'before',
#  'TC-14',
#  'NUTE',
#  'shake',
#  'what',
#  'what',
#  'do',
#  'you',
#  'say',
#  'tc-14',
#  'the',
#  'Ambassadors',
#  'be',
#  'Jedi',
#  'Knights',
#  'I',
#  'believe',
#  'DOFINE',
#  'I',
#  'know',
#  'it',
#  'they',
#  'be',
#  'send',
#  'to',
#  'force',
#  'a',
#  'settlement',
#  'eh',
#  'blind',
#  'I',
#  'we',
#  'be',
#  'do',
#  'for',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'HALLWAY',
#  'a',
#  'hologram',
#  'of',
#  'NUTE',
#  'surround',
#  'by',
#  'BATTLE',
#  'DROIDS',
#  'appear',
#  'in',
#  'the',
#  'conference',
#  'room',
#  'hallway',
#  'NUTE',
#  'they',
#  'must',
#  'be',
#  'dead',
#  'by',
#  'now',
#  'blast',
#  'what',
#  'be',
#  'leave',
#  'of',
#  'they',
#  'the',
#  'hologram',
#  'fade',
#  'off',
#  'as',
#  'a',
#  'BATTLE',
#  'DROID',
#  'OWO-1',
#  'cautiously',
#  'open',
#  'the',
#  'door',
#  'a',
#  'deadly',
#  'green',
#  'cloud',
#  'billow',
#  'from',
#  'the',
#  'room',
#  'BATTLE',
#  'DROIDS',
#  'cock',
#  'their',
#  'weapon',
#  'as',
#  'a',
#  'figure',
#  'stumble',
#  'out',
#  'of',
#  'the',
#  'smoke',
#  'it',
#  'be',
#  'TC-14',
#  'carry',
#  'the',
#  'tray',
#  'of',
#  'drink',
#  'TC14',
#  'oh',
#  'excuse',
#  'I',
#  'so',
#  'sorry',
#  'the',
#  'PROTOCOL',
#  'DROID',
#  'pass',
#  'the',
#  'armed',
#  'camp',
#  'just',
#  'as',
#  'two',
#  'flash',
#  'laser',
#  'sword',
#  'fly',
#  'out',
#  'of',
#  'the',
#  'deadly',
#  'fog',
#  'cut',
#  'down',
#  'several',
#  'BATTLE',
#  'DROIDS',
#  'before',
#  'they',
#  'can',
#  'fire',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'BRIDGE',
#  'the',
#  'bridge',
#  'be',
#  'a',
#  'cocophony',
#  'of',
#  'alarm',
#  'nute',
#  'and',
#  'RUNE',
#  'watch',
#  'OWO-1',
#  'on',
#  'the',
#  'viewscreen',
#  'owo-1',
#  'not',
#  'sure',
#  'exactly',
#  'what',
#  'OWO-1',
#  'be',
#  'suddenly',
#  'cut',
#  'in',
#  'half',
#  'in',
#  'mid',
#  'sentence',
#  'RUNE',
#  'give',
#  'NUTE',
#  'a',
#  'worried',
#  'look',
#  'NUTE',
#  'what',
#  'in',
#  'blaze',
#  'be',
#  'go',
#  'on',
#  'down',
#  'there',
#  'RUNE',
#  'have',
#  'you',
#  'ever',
#  'encounter',
#  'a',
#  'Jedi',
#  'Knight',
#  'before',
#  'sir',
#  'nute',
#  'well',
#  'not',
#  'exactly',
#  'but',
#  'I',
#  "don't",
#  '(panicked',
#  'seal',
#  'off',
#  'the',
#  'bridge',
#  'RUNE',
#  'that',
#  'wo',
#  "n't",
#  'be',
#  'enough',
#  'sir',
#  'the',
#  'door',
#  'to',
#  'the',
#  'bridge',
#  'SLAM',
#  'shut',
#  'NUTE',
#  'I',
#  'want',
#  'destroyer',
#  'droid',
#  'up',
#  'here',
#  'at',
#  'once',
#  'RUNE',
#  'we',
#  'will',
#  'not',
#  'survive',
#  'this',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'HALLWAY',
#  'OUTSIDE',
#  'BRIDGE',
#  'QUI',
#  'GON',
#  'cut',
#  'several',
#  'BATTLE',
#  'DROIDS',
#  'in',
#  'half',
#  'create',
#  'a',
#  'shower',
#  'of',
#  'spark',
#  'and',
#  'metal',
#  'part',
#  'OBI',
#  'WAN',
#  'raise',
#  'his',
#  'hand',
#  'send',
#  'several',
#  'BATTLE',
#  'DROIDS',
#  'crash',
#  'into',
#  'the',
#  'wall',
#  'QUI',
#  'GON',
#  'make',
#  'his',
#  'way',
#  'to',
#  'the',
#  'bridge',
#  'door',
#  'and',
#  'begin',
#  'to',
#  'cut',
#  'through',
#  'it',
#  'INT',
#  'FEDERATION',
#  'BATTLESHIP',
#  'BRIDGE',
#  'the',
#  'CREW',
#  'be',
#  'very',
#  'nervous',
#  'as',
#  'spark',
#  'start',
#  'fly',
#  'around',
#  'the',
#  'bridge',
#  'door',
#  'QUI',
#  'GON',
#  'and',
#  'OBI',
#  'WAN',
#  'be',
#  'on',
#  'the',
#  'view',
#  'screen',
#  'NUTE',
#  'close',
#  'the',
#  'blast',
#  'door',
#  'the',
#  'huge',
#  'very',
#  'thick',
#  'blast',
#  'door',
#  'slam',
#  'shut',
#  'follow',
#  'by',
#  'a',
#  'second',
#  'door',
#  'then',
#  'a',
#  'third',
#  'there',
#  'be',
#  ...]

# %%
def load_lemmas(lemmas_dir):
    cwd = os.getcwd()
    os.chdir(lemmas_dir)
    lemmas_in_docs = []
    try:
        for doc_path in os.listdir():
            with open(doc_path, "r", encoding="UTF-8") as file:
                lemmas = file.readlines()
            
            lemmas = list(map(lambda lemma: lemma.strip(), lemmas))
            lemmas_in_docs.append(lemmas)
            
    except FileNotFoundError:
        traceback.print_exc()
    finally:
        os.chdir(cwd)
    
    return lemmas_in_docs

# %%
def docs_with_query_lemma(query_word, docs, doc_indexes, nlp):
    query_lemma_doc = nlp(query_word)
    query_lemma = query_lemma_doc[0].lemma_
    
    result = set()
    for i, doc in enumerate(docs):
        if query_word in doc:
            result.add(doc_indexes[i])
    return result


sw_lemmas = load_lemmas(sw_lemmas_dir)
no_lemmas = sum(list(map(len, sw_lemmas)))
print(f'Total number of words = {no_lemmas}')

doc_indexation = [1,2,3,4,5,6,7]

luke_eps_lem = docs_with_query_lemma("Luke", sw_lemmas, doc_indexation, nlp)
leia_eps_lem = docs_with_query_lemma("Leia", sw_lemmas, doc_indexation, nlp)

luke_and_leia_eps_lem = leia_eps_lem.intersection(luke_eps_lem)
# Out:
# Total number of words = 199216

# %%
print(f"Luke Skywalker was mentioned in episodes {luke_eps_lem}")
print(f"Leia Organa was mentioned in episodes {leia_eps_lem}")
print()
print(f"They were both mentioned in episodes {luke_and_leia_eps_lem}")
# Out:
# Luke Skywalker was mentioned in episodes {3, 4, 5, 6, 7}
# Leia Organa was mentioned in episodes {3, 4, 5, 6, 7}
#
# They were both mentioned in episodes {3, 4, 5, 6, 7}

# %% [markdown]
# #### 2. Czas działania

# %%
nlp = spacy.load('en_core_web_sm')

def brute_force_intersection(word_1, word_2, doc_indexes, docs):
    set_1 = docs_with_query_lemma(word_1, docs, doc_indexes, nlp)
    set_2 = docs_with_query_lemma(word_2, docs, doc_indexes, nlp)
    return set_1.intersection(set_2)

    
doc_indexation = [1,2,3,4,5,6,7]
measure_time(lambda: brute_force_intersection("Luke", "Leia", doc_indexation, sw_lemmas),
             "Search 'Luke' and 'Leia'")
measure_time(lambda: brute_force_intersection("Dalek", "Doctor", doc_indexation, sw_lemmas),
             "Search 'Dalek' and 'Doctor'")
# Out:
# Search 'Luke' and 'Leia': 0.01011 [s]
# Search 'Dalek' and 'Doctor': 0.00805 [s]
# set()

# %% [markdown]
# ### II sposób - *macierz incydencji*
#
# 1. Wczytanie plików jak w sposobie I
# 2. Tokenizacja i lematyzacja.
# 3. Stworzenie macierzy A o wym. T x N, gdzie T to liczba wyrazów, a N, to takiej, że:
#     a. każdy rząd odpowiada jednemu słowu, a kazdy dokument - jednej kolumnie (zachowany porządek lesykograficzny)
#     b. pole równa się 1, jesli słowo odpowiadające danemu rzędowi znajduje sie w dokumencie odpowiadajace danemu dokumentowi lub 0 wpp
# 4. Znajdujemy odpowiadające szukanym słowom wiersze, które traktujemy jak binarne wektory. Dokonujemy na nich operacji logicznych i otrzymujemy wynik.

# %% [markdown]
# ![matrix](dataset/images/incidence_matrix.png)

# %%
class IncidenceMatrix:
    def __init__(self, words_in_docs, docs_indexation):
        self.docs_indexation = docs_indexation

        sorted_words = self.__sort_without_dup(reduce(lambda l1, l2: l1 + l2, words_in_docs, []))
        self.words_indexation = {sorted_words[i]: i for i in range(len(sorted_words))}
        self.matrix = [[1 if word in doc_words else 0
                        for doc_words in words_in_docs]
                       for word in sorted_words]
        self.__nlp = spacy.load('en_core_web_sm')

    def __sort_without_dup(self, list_with_dup):  # list_with_dup has hashable elements
        return sorted(list(set(list_with_dup)))

    def intersect(self, word_1, word_2):
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        lem_1, lem_2 = word_to_lemma(word_1), word_to_lemma(word_2)
        ind_1, ind_2 = self.words_indexation.get(lem_1), self.words_indexation.get(lem_2)
        
        if ind_1 is None or ind_2 is None:
            return set()
        
        vec_1, vec_2 = self.matrix[ind_1], self.matrix[ind_2]
        intersection = [min(vec_1[i], vec_2[i]) for i in range(len(vec_1))]
        result = set()

        for i in range(len(intersection)):
            if intersection[i] == 1:
                result.add(self.docs_indexation[i])
        return result

# %%
def test_class_with_intersection(class_constructor, docs, doc_indexation, queries):
    class_obj = measure_time(lambda: class_constructor(docs, doc_indexation),
                            f"{class_constructor.__name__} construction time")
    for word1, word2, message in queries:
        measure_time(lambda: class_obj.intersect(word1, word2), message)

# time tests

test_class_with_intersection(IncidenceMatrix, sw_lemmas, [1,2,3,4,5,6,7], 
                            [("Luke", "Leia", "'Luke' and 'Leia' search time"),
                              ("Doctor", "Dalek", "'Doctor' and 'Dalek' search time")])
# Out:
# IncidenceMatrix construction time: 22.59337 [s]
# 'Luke' and 'Leia' search time: 0.01 [s]
# 'Doctor' and 'Dalek' search time: 0.01 [s]

# %% [markdown]
# ### III sposób - odwrócona macierz incydencji
#
# Macierz incydencji to macierz rzadka => lepiej zapamiętywać tylko dokumenty w których słowo występuje.

# %% [markdown]
# **Zasadnicza idea**
#
# Trzymamy słownik ze słowami zawartymi w dokumentach.
#
# Każda wartość w słowniku to lista z indeksami dokumentów, w których występuje **uporzadkowana rosnąco**

# %% [markdown]
# ![img](dataset/images/inv_ind_schema.png)

# %%
class InvertedIndex:
    def __init__(self, words_in_docs, docs_indexation):
        self.docs_indexation = docs_indexation
        unsorted_tuples = reduce(lambda l1, l2: l1 + self.__give_word_index(l2),
                                 zip(words_in_docs, range(0, len(words_in_docs))),
                                 [])
        sorted_tuples = sorted(unsorted_tuples)  #automatic radix sort
        self.dictionary = self.__create_dictionary(sorted_tuples)
        self.__nlp = spacy.load("en_core_web_sm")

    def __give_word_index(self, info_tuple):  # info_tuple =  (["the", "great", "game"...],  5)
        words_in_doc, no_doc = info_tuple
        return list(set(map(lambda word: (word, no_doc), words_in_doc)))  # [("the", 5), ("great", 5), ("game", 5) ...]

    def __create_dictionary(self, sorted_tuples_list):  # sorted_tuples_list => [("a", 3), ("a", 5)
        result_dict = {}
        for word, no_document in sorted_tuples_list:
            if word not in result_dict:
                result_dict[word] = [no_document]
            else:
                posting = result_dict[word]
                if posting[-1] != no_document:
                    result_dict[word].append(no_document)

        return result_dict

    def intersect(self, word_1, word_2):
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        result_doc_ids = set()
        p1, p2 = 0, 0
        docs_1, docs_2 = self.dictionary.get(word_to_lemma(word_1)), \
                         self.dictionary.get(word_to_lemma(word_2))
        if docs_1 is None or docs_2 is None:
            return set()
        n1, n2 = len(docs_1), len(docs_2)
        while p1 < n1 and p2 < n2:
            if docs_1[p1] == docs_2[p2]:
                result_doc_ids.add(docs_1[p1])
                p1 += 1
                p2 += 1
            elif docs_1[p1] < docs_2[p2]:
                p1 += 1
            else:
                p2 += 1
        return {self.docs_indexation[doc_id] for doc_id in result_doc_ids}

# %% [markdown]
# ![inverted_index_creation](dataset/images/inverted_indexes_construction.png)

# %%
    def intersect(self, word_1, word_2):
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        result_doc_ids = set()
        p1, p2 = 0, 0
        docs_1, docs_2 = self.dictionary.get(word_to_lemma(word_1)), \
                         self.dictionary.get(word_to_lemma(word_2))
        if docs_1 is None or docs_2 is None:
            return set()
        n1, n2 = len(docs_1), len(docs_2)
        while p1 < n1 and p2 < n2:
            if docs_1[p1] == docs_2[p2]:
                result_doc_ids.add(docs_1[p1])
                p1 += 1
                p2 += 1
            elif docs_1[p1] < docs_2[p2]:
                p1 += 1
            else:
                p2 += 1
        return {self.docs_indexation[doc_id] for doc_id in result_doc_ids}

# %%
# time tests
query = [("Luke", "Leia", "'Luke' and 'Leia' search time"),
         ("Doctor", "Dalek", "'Doctor' and 'Dalek' search time")]
test_class_with_intersection(InvertedIndex, sw_lemmas, [1,2,3,4,5,6,7], query)
# Out:
# InvertedIndex construction time: 0.49017 [s]
# 'Luke' and 'Leia' search time: 0.00808 [s]
# 'Doctor' and 'Dalek' search time: 0.0 [s]

# %%
all_lemmas = load_lemmas(all_lemmas_dir)   # zbiór ponad tysiaca scenariuszy 
query = [("Luke", "Leia", "'Luke' and 'Leia' search time"),
         ("the", "lightsaber", "'the' and 'lightsaber' search time")]
docs_indexation = list(range(len(all_lemmas)))

print("Brute force aproach:")
for word1, word2, message in query:
    measure_time(lambda: brute_force_intersection(word1, word2, docs_indexation, all_lemmas),
             f"Search '{word1}' and '{word2}'")

print()
print("Inverted indexation: ")
test_class_with_intersection(InvertedIndex, all_lemmas, docs_indexation, query)
# Out:
# Search 'Luke' and 'Leia': 0.89913 [s]
# Search 'the' and 'lightsaber': 0.31617 [s]
# InvertedIndex construction time: 122.12126 [s]
# 'Luke' and 'Leia' search time: 0.00806 [s]
# 'the' and 'lightsaber' search time: 0.00996 [s]

# %% [markdown]
# ### Sposób III z modyfikacją - użycie skiplisty
# Najefektywniejsze: dla równorozdzielonych skip_linków co sqrt(p), gdzie p to długość listy.

# %% [markdown]
# ![skip_list](dataset/images/skip_list.png)

# %%
class SkipListNode:
    def __init__(self, value, skip_index=None):
        self.value = value
        self.skip_index = skip_index

# %%
class InvertedIndexWithSkipLists:
    def __init__(self, words_in_docs, docs_indexation):
        self.docs_indexation = docs_indexation
        unsorted_tuples = reduce(lambda l1, l2: l1 + self.__give_word_index(l2),
                                 zip(words_in_docs, range(0, len(words_in_docs))),
                                 [])
        sorted_tuples = sorted(unsorted_tuples)  # automatic radix sort
        self.dictionary = self.__create_dictionary(sorted_tuples)
        self.__add_skip_links()
        self.__nlp = spacy.load("en_core_web_sm")

    def __give_word_index(self, info_tuple):  # info_tuple =  (["the", "great", "game"...],  5)
        words_in_doc, no_doc = info_tuple
        return list(
            set(map(lambda word: (word, no_doc), words_in_doc)))  # [("the", 5), ("great", 5), ("game", 5) ...]

    def __create_dictionary(self, sorted_tuples):
        result_dict = {}
        for word, no_document in sorted_tuples:
            if word not in result_dict:
                result_dict[word] = [SkipListNode(no_document)]
            else:
                posting = result_dict[word]
                if posting[-1] != no_document:
                    result_dict[word].append(SkipListNode(no_document))
        return result_dict

    def __add_skip_links(self):
        for skip_list in self.dictionary.values():
            n = len(skip_list)
            step = ceil(sqrt(n))
            i = 0
            while i < n:
                skip_list[i].skip_index = min(i + step, n - 1)
                i += step

    def intersect(self, word_1, word_2):
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        result_doc_ids = set()
        p1, p2 = 0, 0
        docs_1, docs_2 = self.dictionary[word_to_lemma(word_1)], \
                         self.dictionary[word_to_lemma(word_2)]
        if docs_1 is None or docs_2 is None:
            return set()
        n1, n2 = len(docs_1), len(docs_2)

        while p1 < n1 and p2 < n2:
            if docs_1[p1].value == docs_2[p2].value:
                result_doc_ids.add(docs_1[p1].value)
                p1 += 1
                p2 += 1
            elif docs_1[p1].value < docs_2[p2].value:
                skip_ind_1 = docs_1[p1].skip_index
                if skip_ind_1 is not None and \
                        docs_1[skip_ind_1].value < docs_2[p2].value:
                    while skip_ind_1 is not None and \
                            docs_1[skip_ind_1].value < docs_2[p2].value:
                        p1 = skip_ind_1
                        skip_ind_1 = docs_1[p1].skip_index
                else:
                    p1 += 1
            else:
                skip_ind_2 = docs_2[p2].skip_index
                if skip_ind_2 is not None and \
                        docs_2[skip_ind_2].value < docs_1[p1].value:
                    while skip_ind_2 is not None and \
                            docs_2[skip_ind_2].value < docs_1[p1].value:
                        p2 = skip_ind_2
                        skip_ind_2 = docs_2[p2].skip_index
                else:
                    p2 += 1
        return {self.docs_indexation[doc_id] for doc_id in result_doc_ids}

# %%
    def intersect(self, word_1, word_2):
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        result_doc_ids = set()
        p1, p2 = 0, 0
        docs_1, docs_2 = self.dictionary[word_to_lemma(word_1)], \
                         self.dictionary[word_to_lemma(word_2)]
        if docs_1 is None or docs_2 is None:
            return set()
        n1, n2 = len(docs_1), len(docs_2)

        while p1 < n1 and p2 < n2:
            if docs_1[p1].value == docs_2[p2].value:
                result_doc_ids.add(docs_1[p1].value)
                p1 += 1
                p2 += 1
            elif docs_1[p1].value < docs_2[p2].value:
                skip_ind_1 = docs_1[p1].skip_index
                if skip_ind_1 is not None and \
                        docs_1[skip_ind_1].value < docs_2[p2].value:
                    while skip_ind_1 is not None and \
                            docs_1[skip_ind_1].value < docs_2[p2].value:
                        p1 = skip_ind_1
                        skip_ind_1 = docs_1[p1].skip_index
                else:
                    p1 += 1
            else:
                skip_ind_2 = docs_2[p2].skip_index
                if skip_ind_2 is not None and \
                        docs_2[skip_ind_2].value < docs_1[p1].value:
                    while skip_ind_2 is not None and \
                            docs_2[skip_ind_2].value < docs_1[p1].value:
                        p2 = skip_ind_2
                        skip_ind_2 = docs_2[p2].skip_index
                else:
                    p2 += 1
        return {self.docs_indexation[doc_id] for doc_id in result_doc_ids}

# %%
query = [("the", "a", "'the' and 'a' search time"),
        ("Luke", "Leia", "'Luke' and 'Leia' search time"),
         ("the", "lightsaber", "'the' and 'lightsaber' search time")]

docs_indexation = list(range(len(all_lemmas)))
test_class_with_intersection(InvertedIndex, all_lemmas, docs_indexation, query)
print()
test_class_with_intersection(InvertedIndexWithSkipLists, all_lemmas, docs_indexation, query)
# Out:
# InvertedIndex construction time: 168.21737 [s]
# 'the' and 'a' search time: 0.08 [s]
# 'Luke' and 'Leia' search time: 0.01 [s]
# 'the' and 'lightsaber' search time: 0.0 [s]
# InvertedIndexWithSkipLists construction time: 173.20083 [s]
# 'the' and 'a' search time: 0.05 [s]
# 'Luke' and 'Leia' search time: 0.0 [s]
# 'the' and 'lightsaber' search time: 0.01 [s]

# %% [markdown]
# ## Czego nam brakuje?
#
# 1. Odporności na literówki
# 2. Wyszukiwanie słów w danej odległości od siebie (np. ("May", "Force", 2))
# 3. Niebinarność:
#      1. wartościowanie słów (np. na bazie częstości wystąpień)
#      2. wartościowanie wyników (lepsze dopasowania powinny być wyżej)

# %% [markdown]
# ## Indeksy pozycyjne (ang. positional indexes)
# **Rozwiązanie 2 problemu**

# %% [markdown]
# ![positional_index](dataset/images/positional_index.png)

# %%
class PositionalIndexes:
    def __init__(self, words_in_docs, docs_indexation):
        self.docs_indexation = docs_indexation
        unsorted_tuples = reduce(lambda l1, l2: l1 + self.__give_word_index_and_position(l2),
                                 zip(words_in_docs, range(0, len(words_in_docs))),
                                 [])

        sorted_tuples = sorted(unsorted_tuples)
        self.dictionary = self.__create_dictionary(sorted_tuples)
        self.__nlp = spacy.load("en_core_web_sm")

    def __give_word_index_and_position(self, info_tuple):  # info_tuple =  (["the", "great", "game"...],  5)
        words_in_doc, no_doc = info_tuple
        words_with_position = zip(words_in_doc, range(len(words_in_doc)))
        return list(
            map(lambda x: (x[0], no_doc, x[1]),
                words_with_position))

    def __create_dictionary(self, sorted_tuples):
        def add_no_occurrences(dictionary):
            no_occurrences = sum(map(len, dictionary.values()))
            return no_occurrences, dictionary

        result_dict = {}
        for word, no_doc, pos in sorted_tuples:
            result_dict.setdefault(word, dict())
            result_dict[word].setdefault(no_doc, [])
            result_dict[word][no_doc].append(pos)

        result_dict = {word: add_no_occurrences(word_dict)
                       for word, word_dict in result_dict.items()}
        # result_dict = dict(map(add_no_occurrences, result_dict.values()))
        return result_dict

    def positional_intersect(self, word_1, word_2, k):  # k - odległość miedzy słowami jest mniejsza lub równa k
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        result = set()
        p1, p2 = 0, 0
        (_, doc_1) = self.dictionary.get(word_to_lemma(word_1))  # we omit frequency
        (_, doc_2) = self.dictionary.get(word_to_lemma(word_2))
        n1, n2 = len(doc_1), len(doc_2)
        while p1 < n1 and p2 < n2:
            doc_ids_1, doc_ids_2 = list(doc_1.keys()), list(doc_2.keys())
            doc_id_1, doc_id_2 = doc_ids_1[p1], doc_ids_2[p2]
            if doc_id_1 == doc_id_2:
                retrieved_positions = self.__check_positions(doc_id_1,
                                                             doc_1[doc_id_1], doc_2[doc_id_2], k)
                result.update(retrieved_positions)
                p1 += 1
                p2 += 1
            elif doc_id_1 < doc_id_2:
                p1 += 1
            else:
                p2 += 1
        return result

    def __check_positions(self, doc_id, pos_list_1, pos_list_2, k):
        result, tmp = set(), []
        p1, p2 = 0, 0
        n1, n2 = len(pos_list_1), len(pos_list_2)
        while p1 < n1:
            while p2 < n2:
                if abs(pos_list_1[p1] - pos_list_2[p2]) <= k:
                    tmp.append(pos_list_2[p2])
                elif pos_list_2[p2] > pos_list_1[p1]:
                    break
                p2 += 1
                while tmp != [] and abs(tmp[0] - pos_list_1[p1]) > k:
                    del tmp[0]
                for pos_2 in tmp:
                    result.add((self.docs_indexation[doc_id], pos_list_1[p1], pos_2))

            p1 += 1

        return result

# %%
    def positional_intersect(self, word_1, word_2, k):  # k - odległość miedzy słowami jest mniejsza lub równa k
        def word_to_lemma(word):
            lemma_doc = self.__nlp(word)
            return lemma_doc[0].lemma_

        result = set()
        p1, p2 = 0, 0
        (_, doc_1) = self.dictionary.get(word_to_lemma(word_1))  # we omit frequency
        (_, doc_2) = self.dictionary.get(word_to_lemma(word_2))
        n1, n2 = len(doc_1), len(doc_2)
        while p1 < n1 and p2 < n2:
            doc_ids_1, doc_ids_2 = list(doc_1.keys()), list(doc_2.keys())
            doc_id_1, doc_id_2 = doc_ids_1[p1], doc_ids_2[p2]
            if doc_id_1 == doc_id_2:
                retrieved_positions = self.__check_positions(doc_id_1,
                                                             doc_1[doc_id_1], doc_2[doc_id_2], k)
                result.update(retrieved_positions)
                p1 += 1
                p2 += 1
            elif doc_id_1 < doc_id_2:
                p1 += 1
            else:
                p2 += 1
        return result

# %%
    def __check_positions(self, doc_id, pos_list_1, pos_list_2, k):
        result, tmp = set(), []
        p1, p2 = 0, 0
        n1, n2 = len(pos_list_1), len(pos_list_2)
        while p1 < n1:
            while p2 < n2:
                if abs(pos_list_1[p1] - pos_list_2[p2]) <= k:
                    tmp.append(pos_list_2[p2])
                elif pos_list_2[p2] > pos_list_1[p1]:
                    break
                p2 += 1
                while tmp != [] and abs(tmp[0] - pos_list_1[p1]) > k:
                    del tmp[0]
                for pos_2 in tmp:
                    result.add((self.docs_indexation[doc_id], pos_list_1[p1], pos_2))

            p1 += 1

        return result

# %%
words_in_docs = load_lemmas(sw_lemmas)
positional_ind = PositionalIndexes(words_in_docs, [1, 2, 3, 4, 5, 6, 7])

print(positional_ind.positional_intersect("Master", "Yoda", 1))

may_the_force = positional_ind.positional_intersect("may", "you", 5)

print(sorted(list(filter(lambda x: x[2] - x[1] == 5, may_the_force))))
